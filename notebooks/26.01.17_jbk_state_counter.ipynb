# %%
from statecounter import Counter, Manager

with Manager():
    A = Counter(num_states=2, name='A')
    B = Counter(num_states=3, name='B')

    # C is derived from A and B via product
    C = A * B  # 6 states (2 × 3)
    C.name = 'C'
    C.print_dag()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5 B = Counter(num_states=3, name='B')
#       7 # C is derived from A and B via product
# ----> 8 C = A * B  # 6 states (2 × 3)
#       9 C.name = 'C'
#      10 C.print_dag()
#
# TypeError: unsupported operand type(s) for *: 'Counter' and 'Counter'
