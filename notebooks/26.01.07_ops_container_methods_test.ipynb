# %%
import poolparty as pp; pp.init()

bg_pool = pp.from_seq('A'*8)

result_pool = bg_pool.mutagenize_scan(mutagenize_length=5, num_mutations=1, mode='sequential', spacer_str='.')

print('final counter')
result_pool.counter.print_tree()

print('final library')
result_pool.print_library()
# Out:
# debugging here
# pool[1].state (counter, io=0, n=4)
# └── [op=Product]
#     ├── op[1]:mutagenize_scan(marker_scan).state (counter, io=0, n=4)
#     └── pool[0].state (counter, io=0, n=1)
#         └── [op=Passthrough]
#             └── op[0]:from_seq.state (counter, io=0, n=1)
# pool[2].state (counter, io=0, n=60)
# └── [op=Product]
#     ├── op[2]:mutagenize_scan(mutagenize).state (counter, io=0, n=15)
#     ├── op[1]:mutagenize_scan(marker_scan).state (counter, io=0, n=4)
#     └── pool[0].state (counter, io=0, n=1)
#         └── [op=Passthrough]
#             └── op[0]:from_seq.state (counter, io=0, n=1)
# final counter
# pool[2].state (counter, io=0, n=60)
# └── [op=Product]
#     ├── op[2]:mutagenize_scan(mutagenize).state (counter, io=0, n=15)
#     ├── op[1]:mutagenize_scan(marker_scan).state (counter, io=0, n=4)
#     └── pool[0].state (counter, io=0, n=1)
#         └── [op=Passthrough]
#             └── op[0]:from_seq.state (counter, io=0, n=1)
# final library
# pool[2]: seq_length=None, num_states=60
# state  seq
#     0  .cAAAA.AAA
#     1  .gAAAA.AAA
#     2  .tAAAA.AAA
#     3  .AcAAA.AAA
#     4  .AgAAA.AAA
#     5  .AtAAA.AAA
#     6  .AAcAA.AAA
#     7  .AAgAA.AAA
#     8  .AAtAA.AAA
#     9  .AAAcA.AAA
#    10  .AAAgA.AAA
#    11  .AAAtA.AAA
#    12  .AAAAc.AAA
#    13  .AAAAg.AAA
#    14  .AAAAt.AAA
#    15  A.cAAAA.AA
#    16  A.gAAAA.AA
#    17  A.tAAAA.AA
#    18  A.AcAAA.AA
#    19  A.AgAAA.AA
#    20  A.AtAAA.AA
#    21  A.AAcAA.AA
#    22  A.AAgAA.AA
#    23  A.AAtAA.AA
#    24  A.AAAcA.AA
#    25  A.AAAgA.AA
#    26  A.AAAtA.AA
#    27  A.AAAAc.AA
#    28  A.AAAAg.AA
#    29  A.AAAAt.AA
#    30  AA.cAAAA.A
#    31  AA.gAAAA.A
#    32  AA.tAAAA.A
#    33  AA.AcAAA.A
#    34  AA.AgAAA.A
#    35  AA.AtAAA.A
#    36  AA.AAcAA.A
#    37  AA.AAgAA.A
#    38  AA.AAtAA.A
#    39  AA.AAAcA.A
#    40  AA.AAAgA.A
#    41  AA.AAAtA.A
#    42  AA.AAAAc.A
#    43  AA.AAAAg.A
#    44  AA.AAAAt.A
#    45  AAA.cAAAA.
#    46  AAA.gAAAA.
#    47  AAA.tAAAA.
#    48  AAA.AcAAA.
#    49  AAA.AgAAA.
#    50  AAA.AtAAA.
#    51  AAA.AAcAA.
#    52  AAA.AAgAA.
#    53  AAA.AAtAA.
#    54  AAA.AAAcA.
#    55  AAA.AAAgA.
#    56  AAA.AAAtA.
#    57  AAA.AAAAc.
#    58  AAA.AAAAg.
#    59  AAA.AAAAt.
# Pool(id=2, name='pool[2]', op='op[2]:mutagenize_scan(mutagenize)', num_states=60)
