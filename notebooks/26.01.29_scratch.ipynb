# %%
import poolparty as pp
from typing import Literal

def workload_from_iupac(
    seq_len: int = 5,
    num_seqs: int = 100,
    mode: Literal['random', 'sequential'] = 'random',
    use_styles: bool = False,
    use_cards: bool = False
):
    pp.init()
    pp.toggle_styles(on=use_styles)
    pp.toggle_cards(on=use_cards)
    seq = 'N'*seq_len
    pool = pp.from_iupac(iupac_seq=seq, mode=mode)
    return pool.generate_library(num_seqs=num_seqs)

workload_from_iupac(seq_len=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 18
#      15     pool = pp.from_iupac(iupac_seq=seq, mode=mode)
#      16     return pool.generate_library(num_seqs=num_seqs)
# ---> 18 workload_from_iupac(seq_len=100)
#
# Cell In[2], line 16, in workload_from_iupac(seq_len, num_seqs, mode, use_styles, use_cards)
#      14 seq = 'N'*seq_len
#      15 pool = pp.from_iupac(iupac_seq=seq, mode=mode)
# ---> 16 return pool.generate_library(num_seqs=num_seqs)
#
# File <@beartype(poolparty.pool.Pool.generate_library) at 0x11d531e10>:343, in generate_library(__beartype_get_violation, __beartype_conf, __beartype_object_4786293824, __beartype_object_140323208602256, __beartype_object_140324025169584, __beartype_getrandbits, __beartype_object_4525382128, __beartype_object_4510666096, __beartype_object_4787031424, __beartype_object_140324026223552, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/github/poolparty-statetracker/poolparty/src/poolparty/pool.py:314, in Pool.generate_library(self, num_cycles, num_seqs, seed, init_state, seqs_only, report_design_cards, aux_pools, pools_to_report, organize_columns_by, _include_inline_styles, report_seq, report_pool_seqs, report_pool_states, report_op_states, report_op_keys)
#     312         party._config._design_cards = orig_design_cards
#     313 else:
# --> 314     return generate_library(
#     315         pool=self,
#     316         num_cycles=num_cycles,
#     317         num_seqs=num_seqs,
#     318         seed=seed,
#     319         init_state=init_state,
#     320         seqs_only=seqs_only,
#     321         report_design_cards=report_design_cards,
#     322         aux_pools=aux_pools,
#     323         pools_to_report=pools_to_report,
#     324         organize_columns_by=organize_columns_by,
#     325         _include_inline_styles=_include_inline_styles,
#     326     )
#
# File <@beartype(poolparty.generate_library.generate_library) at 0x11d5552d0>:256, in generate_library(__beartype_object_140323210489168, __beartype_get_violation, __beartype_conf, __beartype_object_4786293824, __beartype_object_140323208602256, __beartype_object_140324025169584, __beartype_getrandbits, __beartype_object_4525382128, __beartype_object_4510666096, __beartype_object_140324026223552, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/github/poolparty-statetracker/poolparty/src/poolparty/generate_library.py:110, in generate_library(pool, num_cycles, num_seqs, seed, init_state, seqs_only, report_design_cards, aux_pools, pools_to_report, organize_columns_by, _include_inline_styles)
#     108 for i in range(num_seqs):
#     109     global_state = pool._current_state + i
# --> 110     row = _compute_one(
#     111         pool, sorted_ops, outputs, global_state,
#     112         states, report_design_cards and not suppress_cards,
#     113         ops_to_report, pools_filter, _include_inline_styles
#     114     )
#     115     rows.append(row)
#     117 pool._current_state += num_seqs
#
# File ~/github/poolparty-statetracker/poolparty/src/poolparty/generate_library.py:270, in _compute_one(pool, sorted_ops, outputs, global_state, states, report_design_cards, ops_to_report, pools_filter, include_inline_styles)
#     267     op_rng = op.rng
#     269 # Compute output Seq and design card (handles region wrapping automatically)
# --> 270 output_seq, card = op.compute(parents, op_rng)
#     272 # Store in caches for downstream operations
#     273 seq_cache[op.id] = output_seq
#
# File <@beartype(poolparty.operation.Operation.compute) at 0x11d533ac0>:65, in compute(__beartype_object_140321328569392, __beartype_getrandbits, __beartype_get_violation, __beartype_conf, __beartype_object_4583996672, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/github/poolparty-statetracker/poolparty/src/poolparty/operation.py:273, in Operation.compute(self, parents, rng)
#     249 """Compute output Seq and design card with automatic region handling.
#     250
#     251 This is the public entry point for operations. It handles region
#    (...)
#     270 4. Removes region tags if remove_tags=True and region is a region name
#     271 """
#     272 if self._region is None:
# --> 273     output_seq, card = self._compute_core(parents, rng)
#     274 else:
#     275     # Create context from first parent sequence
#     276     from .utils.region_context import RegionContext
#
# File <@beartype(poolparty.base_ops.from_iupac.FromIupacOp._compute_core) at 0x11d5cb370>:65, in _compute_core(__beartype_object_140321328569392, __beartype_getrandbits, __beartype_get_violation, __beartype_conf, __beartype_object_4583996672, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/github/poolparty-statetracker/poolparty/src/poolparty/base_ops/from_iupac.py:185, in FromIupacOp._compute_core(self, parents, rng)
#     183     if rng is None:
#     184         raise RuntimeError(f"{self.mode.capitalize()} mode requires RNG")
# --> 185     state = rng.integers(0, self._total_states)
#     186 else:
#     187     state_value = self.state.value
#
# File numpy/random/_generator.pyx:679, in numpy.random._generator.Generator.integers()
#
# File numpy/random/_bounded_integers.pyx:1332, in numpy.random._bounded_integers._rand_int64()
#
# ValueError: high is out of bounds for int64
