# %%
import poolparty as pp
from typing import Literal

pp.init()
seq = 'ACGT<bob/>ACGT'
pool = pp.mutagenize(pool=seq, mode='random', mutation_rate=.3, style='bold yellow')
pool.print_library(num_seqs=10)
# Out:
# pool[1]: seq_length=8, num_states=1
# state  seq
#     0  ACAA<bob/>CCAT
#     0  ACAA<bob/>CCAT
#     0  ACAA<bob/>CCAT
#     0  ACAA<bob/>CCAT
#     0  ACAA<bob/>CCAT
#     0  ACAA<bob/>CCAT
#     0  ACAA<bob/>CCAT
#     0  ACAA<bob/>CCAT
#     0  ACAA<bob/>CCAT
#     0  ACAA<bob/>CCAT
# Pool(id=1, name='pool[1]', op='op[1]:mutagenize', num_states=1)
