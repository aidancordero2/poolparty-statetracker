# %%
import poolparty as pp; pp.init()

# Background sequence and insert
bg = 'AAAAAAAAAA'  # 10 chars
ins = 'TTT'        # 3 chars

# insertion_scan: INSERT at positions (output length = bg + ins = 13)
# Note: pp.init() sets mark_changes=True by default, so inserts appear lowercase
print("=== insertion_scan (insert mode, default) ===")
ins_pool = pp.insertion_scan(bg, ins, positions=[0, 5, 10], mode='sequential', spacer_str='.')
ins_pool.print_library()

# insertion_scan with replace=True: REPLACE at positions (output length = bg = 10)
print("\n=== insertion_scan(replace=True) ===")
rep_pool = pp.insertion_scan(bg, ins, positions=[0, 4, 7], replace=True, mode='sequential')
rep_pool.print_library()

# replacement_scan is now a thin wrapper for insertion_scan(replace=True)
print("\n=== replacement_scan (equivalent to replace=True) ===")
pp.replacement_scan(bg, ins, positions=[0, 4, 7], mode='sequential').print_library()

# mark_changes=False to preserve original case
print("\n=== insertion_scan with mark_changes=False ===")
pp.insertion_scan(bg, ins, positions=[5], mark_changes=False).print_library()

# spacer_str adds spacing around insert
print("\n=== insertion_scan with spacer_str ===")
pp.insertion_scan(bg, ins, positions=[5], spacer_str='.').print_library()
# Out:
# === insertion_scan (insert mode, default) ===
# pool[7]: seq_length=None, num_states=3
# state  seq
#     0  .ttt.AAAAAAAAAA
#     1  AAAAA.ttt.AAAAA
#     2  AAAAAAAAAA.ttt.
#
#
# === insertion_scan(replace=True) ===
# pool[12]: seq_length=None, num_states=3
# state  seq
#     0  tttAAAAAAA
#     1  AAAAtttAAA
#     2  AAAAAAAttt
#
#
# === replacement_scan (equivalent to replace=True) ===
# pool[17]: seq_length=None, num_states=3
# state  seq
#     0  tttAAAAAAA
#     1  AAAAtttAAA
#     2  AAAAAAAttt
#
#
# === insertion_scan with mark_changes=False ===
# pool[21]: seq_length=None, num_states=1
# state  seq
#     0  AAAAATTTAAAAA
#
#
# === insertion_scan with spacer_str ===
# pool[29]: seq_length=None, num_states=1
# state  seq
#     0  AAAAA.ttt.AAAAA
# Pool(id=29, name='pool[29]', op='op[29]:insertion_scan(replace_marker_content)', num_states=1)

# %%
rep_pool.print_tree()
# Out:
# pool[12] (pool, n=3)
# └── op[12]:insertion_scan(replace_marker_content) [mode=fixed, n=1]
#     ├── pool[11] (pool, n=3)
#     │   └── op[11]:insertion_scan(marker_scan) [mode=sequential, n=3]
#     │       └── pool[8] (pool, n=1)
#     │           └── op[8]:from_seq [mode=fixed, n=1]
#     └── pool[10] (pool, n=1)
#         └── op[10]:insertion_scan(swapcase) [mode=fixed, n=1]
#             └── pool[9] (pool, n=1)
#                 └── op[9]:from_seq [mode=fixed, n=1]
# Pool(id=12, name='pool[12]', op='op[12]:insertion_scan(replace_marker_content)', num_states=3)

# %%
ins_pool.print_tree()
# Out:
# pool[7] (pool, n=3)
# └── op[7]:insertion_scan(replace_marker_content) [mode=fixed, n=1]
#     ├── pool[3] (pool, n=3)
#     │   └── op[3]:insertion_scan(marker_scan) [mode=sequential, n=3]
#     │       └── pool[0] (pool, n=1)
#     │           └── op[0]:from_seq [mode=fixed, n=1]
#     └── pool[6] (pool, n=1)
#         └── op[6]:insertion_scan(join) [mode=fixed, n=1]
#             ├── pool[4] (pool, n=1)
#             │   └── op[4]:from_seq [mode=fixed, n=1]
#             ├── pool[2] (pool, n=1)
#             │   └── op[2]:insertion_scan(swapcase) [mode=fixed, n=1]
#             │       └── pool[1] (pool, n=1)
#             │           └── op[1]:from_seq [mode=fixed, n=1]
#             └── pool[5] (pool, n=1)
#                 └── op[5]:from_seq [mode=fixed, n=1]
# Pool(id=7, name='pool[7]', op='op[7]:insertion_scan(replace_marker_content)', num_states=3)
