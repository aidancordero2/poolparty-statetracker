# %%
# Import and initialize poolparty
import poolparty as pp 
pp.init()

template_pool = pp.from_seq('TCCCGACT<cre>GGAAAGCGGGCAGTGAGCACACAGGA</cre>ATTACGG<bc/>AGATCGGA')\
                  .named('template_pool')

mutated_pool = template_pool.stylize(region='cre', style='goldenrod')\
                            .mutagenize(region='cre',
                                        mutation_rate=0.1, 
                                        style='yellow bold',
                                        mode='random', 
                                        num_states=5, 
                                        prefix='mutagenize').named('mutated_pool')\

deletion_pool = template_pool.stylize(region='cre', style='salmon')\
                             .deletion_scan(region='cre', 
                                            deletion_length=6, 
                                            positions=slice(None, None, 5), 
                                            mode='sequential', 
                                            style='red bold',
                                            prefix='delscan').named('deletion_pool')\
                            .repeat_states(2, prefix='v', iter_order=-2)

sites_pool=pp.from_seqs(['AAAAAA','TTTTTT'], 
                        mode='sequential', 
                        iter_order=-1,
                        prefix='site').named('sites_pool')

insertion_pool = template_pool.stylize(region='cre', style='blue')\
                              .insertion_scan(region='cre', 
                                              ins_pool=sites_pool, 
                                              positions=slice(None,None,5), 
                                              replace=True, 
                                              mode='sequential',
                                              prefix='insscan',
                                              prefix_position='pos', 
                                              prefix_insert='ins',
                                              style='cyan bold').named('insertion_pool')
                              
shuffle_pool = template_pool.stylize(region='cre', style='purple')\
                            .shuffle_scan(region='cre', 
                                          shuffle_length=6, 
                                          shuffles_per_position=2,
                                          positions=slice(None, None, 5), 
                                          mode='sequential', 
                                          style='magenta bold',
                                          prefix='shufscan',
                                          prefix_position='pos',
                                          prefix_shuffle='shuf')
                            
L = len('GGAAAGCGGGCAGTGAGCACACAGGA')
#source_pool_a = pp.from_seq('A'*L).stylize(style='green')
#source_pool_b = pp.from_seq('T'*L).stylize(style='red')
recomb_pool = template_pool.recombine(region='cre', 
                                      num_breakpoints=2,
                                      sources=['A'*L, 'T'*L, 'G'*L, 'T'*L],
                                      styles=['green','red', 'blue', 'yellow'],
                                      style_by='source',
                                      mode='random',
                                      num_states=5,
                                      prefix='recomb').named('recomb_pool')

combo_pool = pp.stack([mutated_pool, deletion_pool, insertion_pool, shuffle_pool, recomb_pool])\
    .named('stack_pool')\
    .insert_kmers(region='bc', mode='random', length=5, prefix='bc', style='green bold')\
    .named('combo_pool')\
    .stylize(which='tags', style='gray')

combo_pool.print_library(show_name=True,seed=12)
# Out:
# pool[22]: seq_length=None, num_states=40
# state  name                           seq
#     0  mutagenize_0.bc_0              TCCCGACT<cre>GAGAAGCGGGCAGTGAGCACACAGGA</cre>ATTACGG<bc>CTTCT</bc>AGATCGGA
#     1  mutagenize_1.bc_1              TCCCGACT<cre>GGAAAGCGGGTAGTGAGCACACATGA</cre>ATTACGG<bc>GCCGT</bc>AGATCGGA
#     2  mutagenize_2.bc_2              TCCCGACT<cre>GGAAAGCGGTCAGTAAGCACATAGGA</cre>ATTACGG<bc>TACCG</bc>AGATCGGA
#     3  mutagenize_3.bc_3              TCCCGACT<cre>GGAAAGCGGGCAGTTAGCATACATGA</cre>ATTACGG<bc>ATGAT</bc>AGATCGGA
#     4  mutagenize_4.bc_4              TCCCGACT<cre>GGAACGCGGGCAGTGAGCACACAGGA</cre>ATTACGG<bc>TACCT</bc>AGATCGGA
#     5  delscan_0.v_0.bc_5             TCCCGACT<cre>------CGGGCAGTGAGCACACAGGA</cre>ATTACGG<bc>TATAA</bc>AGATCGGA
#     6  delscan_0.v_1.bc_6             TCCCGACT<cre>------CGGGCAGTGAGCACACAGGA</cre>ATTACGG<bc>AGCTC</bc>AGATCGGA
#     7  delscan_1.v_0.bc_7             TCCCGACT<cre>GGAAA------AGTGAGCACACAGGA</cre>ATTACGG<bc>TGGTG</bc>AGATCGGA
#     8  delscan_1.v_1.bc_8             TCCCGACT<cre>GGAAA------AGTGAGCACACAGGA</cre>ATTACGG<bc>GTTCT</bc>AGATCGGA
#     9  delscan_2.v_0.bc_9             TCCCGACT<cre>GGAAAGCGGG------GCACACAGGA</cre>ATTACGG<bc>TGAGG</bc>AGATCGGA
#    10  delscan_2.v_1.bc_10            TCCCGACT<cre>GGAAAGCGGG------GCACACAGGA</cre>ATTACGG<bc>AACCC</bc>AGATCGGA
#    11  delscan_3.v_0.bc_11            TCCCGACT<cre>GGAAAGCGGGCAGTG------CAGGA</cre>ATTACGG<bc>TCATC</bc>AGATCGGA
#    12  delscan_3.v_1.bc_12            TCCCGACT<cre>GGAAAGCGGGCAGTG------CAGGA</cre>ATTACGG<bc>AGCCA</bc>AGATCGGA
#    13  delscan_4.v_0.bc_13            TCCCGACT<cre>GGAAAGCGGGCAGTGAGCAC------</cre>ATTACGG<bc>ATTAT</bc>AGATCGGA
#    14  delscan_4.v_1.bc_14            TCCCGACT<cre>GGAAAGCGGGCAGTGAGCAC------</cre>ATTACGG<bc>ACGGA</bc>AGATCGGA
#    15  insscan_0.pos_0.ins_0.bc_15    TCCCGACT<cre>AAAAAACGGGCAGTGAGCACACAGGA</cre>ATTACGG<bc>TCCTC</bc>AGATCGGA
#    16  insscan_1.pos_0.ins_1.bc_16    TCCCGACT<cre>TTTTTTCGGGCAGTGAGCACACAGGA</cre>ATTACGG<bc>ATGGG</bc>AGATCGGA
#    17  insscan_2.pos_1.ins_0.bc_17    TCCCGACT<cre>GGAAAAAAAAAAGTGAGCACACAGGA</cre>ATTACGG<bc>CCATT</bc>AGATCGGA
#    18  insscan_3.pos_1.ins_1.bc_18    TCCCGACT<cre>GGAAATTTTTTAGTGAGCACACAGGA</cre>ATTACGG<bc>CACAC</bc>AGATCGGA
#    19  insscan_4.pos_2.ins_0.bc_19    TCCCGACT<cre>GGAAAGCGGGAAAAAAGCACACAGGA</cre>ATTACGG<bc>TTACG</bc>AGATCGGA
#    20  insscan_5.pos_2.ins_1.bc_20    TCCCGACT<cre>GGAAAGCGGGTTTTTTGCACACAGGA</cre>ATTACGG<bc>AGTGG</bc>AGATCGGA
#    21  insscan_6.pos_3.ins_0.bc_21    TCCCGACT<cre>GGAAAGCGGGCAGTGAAAAAACAGGA</cre>ATTACGG<bc>CTCGT</bc>AGATCGGA
#    22  insscan_7.pos_3.ins_1.bc_22    TCCCGACT<cre>GGAAAGCGGGCAGTGTTTTTTCAGGA</cre>ATTACGG<bc>ATCAC</bc>AGATCGGA
#    23  insscan_8.pos_4.ins_0.bc_23    TCCCGACT<cre>GGAAAGCGGGCAGTGAGCACAAAAAA</cre>ATTACGG<bc>GAAGG</bc>AGATCGGA
#    24  insscan_9.pos_4.ins_1.bc_24    TCCCGACT<cre>GGAAAGCGGGCAGTGAGCACTTTTTT</cre>ATTACGG<bc>ATTCG</bc>AGATCGGA
#    25  shufscan_0.pos_0.shuf_0.bc_25  TCCCGACT<cre>GAAGGACGGGCAGTGAGCACACAGGA</cre>ATTACGG<bc>GTCGA</bc>AGATCGGA
#    26  shufscan_1.pos_0.shuf_1.bc_26  TCCCGACT<cre>AGAGGACGGGCAGTGAGCACACAGGA</cre>ATTACGG<bc>ATGAG</bc>AGATCGGA
#    27  shufscan_2.pos_1.shuf_0.bc_27  TCCCGACT<cre>GGAAAGGGCCGAGTGAGCACACAGGA</cre>ATTACGG<bc>GCATT</bc>AGATCGGA
#    28  shufscan_3.pos_1.shuf_1.bc_28  TCCCGACT<cre>GGAAAGCGCGGAGTGAGCACACAGGA</cre>ATTACGG<bc>GGCCA</bc>AGATCGGA
#    29  shufscan_4.pos_2.shuf_0.bc_29  TCCCGACT<cre>GGAAAGCGGGCGTAAGGCACACAGGA</cre>ATTACGG<bc>CGCCT</bc>AGATCGGA
#    30  shufscan_5.pos_2.shuf_1.bc_30  TCCCGACT<cre>GGAAAGCGGGGAGACTGCACACAGGA</cre>ATTACGG<bc>AAGCC</bc>AGATCGGA
#    31  shufscan_6.pos_3.shuf_0.bc_31  TCCCGACT<cre>GGAAAGCGGGCAGTGACAGACCAGGA</cre>ATTACGG<bc>CGACA</bc>AGATCGGA
#    32  shufscan_7.pos_3.shuf_1.bc_32  TCCCGACT<cre>GGAAAGCGGGCAGTGCACGAACAGGA</cre>ATTACGG<bc>ACAAG</bc>AGATCGGA
#    33  shufscan_8.pos_4.shuf_0.bc_33  TCCCGACT<cre>GGAAAGCGGGCAGTGAGCACAGGCAA</cre>ATTACGG<bc>AGGAA</bc>AGATCGGA
#    34  shufscan_9.pos_4.shuf_1.bc_34  TCCCGACT<cre>GGAAAGCGGGCAGTGAGCACAAGCAG</cre>ATTACGG<bc>ACGAG</bc>AGATCGGA
#    35  recomb_0.bc_35                 TCCCGACT<cre>TTTTGGGGGGGTTTTTTTTTTTTTTT</cre>ATTACGG<bc>TTGTG</bc>AGATCGGA
#    36  recomb_1.bc_36                 TCCCGACT<cre>GGGGGGGGGGGGAAATTTTTTTTTTT</cre>ATTACGG<bc>GCGAC</bc>AGATCGGA
#    37  recomb_2.bc_37                 TCCCGACT<cre>TTTGGGGGGGTTTTTTTTTTTTTTTT</cre>ATTACGG<bc>GTCTA</bc>AGATCGGA
#    38  recomb_3.bc_38                 TCCCGACT<cre>GGGGGGGGGGGGGGTTTTAAAAAAAA</cre>ATTACGG<bc>CGCGC</bc>AGATCGGA
#    39  recomb_4.bc_39                 TCCCGACT<cre>GGGGGGGTTTTTTTTTTTTTTTTTTT</cre>ATTACGG<bc>GTCCT</bc>AGATCGGA
# Pool(id=22, name='pool[22]', op='op[22]:stylize', num_states=40)

# %%
combo_pool.print_dag()

# %%
combo_pool.mutagenize?
