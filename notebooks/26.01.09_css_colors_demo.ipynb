# %%
import poolparty as pp; pp.init()

# Show all available named colors
#pp.print_named_colors()

pool = pp.from_seq('AT<cre>CG</cre>AAA').print_library()

pp.clear_highlights()
pp.add_highlight(region='cre', style='underline coral bold')
pool.print_library()
# Out:
# pool[0]: seq_length=7, num_states=1
# state  seq
#     0  AT<cre>CG</cre>AAA
#
# pool[0]: seq_length=7, num_states=1
# state  seq
#     0  AT<cre>CG</cre>AAA
# Pool(id=0, name='pool[0]', op='op[0]:from_seq', num_states=1)

# %%
pp.clear_highlights()
pp.add_highlight(region='cre', style='coral')
pool.print_library()
# Out:
# pool[0]: seq_length=7, num_states=1
# state  seq
#     0  AT<cre>CG</cre>AAA
# Pool(id=0, name='pool[0]', op='op[0]:from_seq', num_states=1)

# %%
pp.clear_highlights()
pp.add_highlight(region='cre', style='bold underline green')
pool.print_library()
# Out:
# pool[0]: seq_length=7, num_states=1
# state  seq
#     0  AT<cre>CG</cre>AAA
# Pool(id=0, name='pool[0]', op='op[0]:from_seq', num_states=1)
